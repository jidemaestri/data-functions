# %% [markdown]
# <a href="https://colab.research.google.com/github/jidemaestri/data-functions/blob/main/opencv_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2

# %%
tesla = mpimg.imread("tesla.jpg")

# %%
plt.imshow(tesla)

# %%
tesla.shape
# Out:
# (179, 281, 3)

# %% [markdown]
# Convert image into grayscale

# %%
tesla_gray = cv2.cvtColor(tesla, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(tesla_gray, cmap="gray")

# %%
tesla_gray.shape
# Out:
# (179, 281)

# %%
plt.imshow(tesla_gray)

# %%
tesla_gray
# Out:
# array([[234, 234, 234, ...,  93, 103,  96],
#        [234, 234, 234, ...,  91,  99, 100],
#        [234, 234, 234, ...,  88,  93,  90],
#        ...,
#        [ 74,  71,  77, ...,  59,  59,  60],
#        [ 74,  70,  77, ...,  59,  59,  60],
#        [ 73,  70,  76, ...,  59,  59,  60]], dtype=uint8)

# %% [markdown]
# Saving the image

# %%
cv2.imwrite("tesla_gray.jpg", tesla_gray)
# Out:
# True

# %% [markdown]
# Detecting objects

# %%
tesla_gray_np = np.copy(tesla_gray)

# %%
tesla_gray_np
# Out:
# array([[234, 234, 234, ...,  93, 103,  96],
#        [234, 234, 234, ...,  91,  99, 100],
#        [234, 234, 234, ...,  88,  93,  90],
#        ...,
#        [ 74,  71,  77, ...,  59,  59,  60],
#        [ 74,  70,  77, ...,  59,  59,  60],
#        [ 73,  70,  76, ...,  59,  59,  60]], dtype=uint8)

# %%
tesla_gray2 = tesla_gray

# %%
tesla_gray2[(tesla_gray2[:,:] < 200)] = 0

# %%
plt.imshow(tesla_gray)

# %%
plt.imshow(tesla_gray2)

# %%
plt.imshow(tesla)

# %%
tesla_copy = np.copy(tesla)

# %%
tesla_copy.shape
# Out:
# (179, 281, 3)

# %%
tesla_copy
# Out:
# array([[[235, 233, 234],
#         [235, 233, 234],
#         [235, 233, 234],
#         ...,
#         [ 94,  94,  92],
#         [104, 104, 102],
#         [ 97,  97,  95]],
#
#        [[235, 233, 234],
#         [235, 233, 234],
#         [235, 233, 234],
#         ...,
#         [ 92,  92,  90],
#         [100, 100,  98],
#         [101, 101,  99]],
#
#        [[235, 233, 234],
#         [235, 233, 234],
#         [235, 233, 234],
#         ...,
#         [ 89,  89,  87],
#         [ 94,  94,  92],
#         [ 91,  91,  89]],
#
#        ...,
#
#        [[ 77,  73,  74],
#         [ 74,  70,  71],
#         [ 80,  76,  77],
#         ...,
#         [ 58,  57,  62],
#         [ 58,  57,  62],
#         [ 59,  58,  63]],
#
#        [[ 77,  73,  74],
#         [ 73,  69,  70],
#         [ 80,  76,  77],
#         ...,
#         [ 58,  57,  62],
#         [ 58,  57,  62],
#         [ 59,  58,  63]],
#
#        [[ 76,  72,  73],
#         [ 73,  69,  70],
#         [ 79,  75,  76],
#         ...,
#         [ 58,  57,  62],
#         [ 58,  57,  62],
#         [ 59,  58,  63]]], dtype=uint8)

# %%
tesla_copy[(tesla_copy[:,:,0] < 50)|(tesla_copy[:,:,1] < 50)|(tesla_copy[:,:,2] < 50)] = 0

# %%
plt.imshow(tesla_copy)
